# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasShafiq/Machine-Learning/blob/ML-Algebra-1/ML_Algebra_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Hello World')
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0,40,1000) #(Start point in time, time required, the details in between)
#distance by the robber
d_r = 2.5 * t
#distance of the police
d_p = 3 * (t-5)
#Ploting the graph
fig, ax = plt.subplots()
plt.title('Bank Robber Problem')
plt.xlabel('Time(In Minutes)')
plt.ylabel('Distance(In Kilometers)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t,d_r,c='blue')
ax.plot(t,d_p,c='green')
